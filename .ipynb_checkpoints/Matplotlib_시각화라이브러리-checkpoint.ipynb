# %%
### matplotlib 불러오기
import matplotlib.pyplot as plt

# %% [markdown]
# ### Line plot

# %%
# 가장 기본적인 그래프
y=[2,4,6]   ### 값이 여러개이어야 하기 때문에 리스트형으로 준비
plt.plot(y) # 그래프 그리는 함수
plt.show() # 그래프 출력

# %%
x=[1,2,3]
y=[2,4,6]   
plt.plot(x,y) # 그래프 그리는 함수(x축,y축)
plt.show() # 그래프 출력

# %% [markdown]
# #### style 적용
#
# ![image.png](attachment:image.png)

# %%
y=[2,4,6] 

plt.plot(y, ls=':') ### ls  라인스타일 
plt.show() # 그래프 출력

# %% [markdown]
# ##### 마커 marker
# ![image.png](attachment:image.png)

# %%
y=[2,4,6]   

plt.plot(y, marker='|') ### marker  마커  
plt.show() # 그래프 출력

# %%
y=[2,4,6]   

plt.plot(y, lw='5') ###   lw 라인 와이드  선의 두께
plt.show()

# %% [markdown]
# ##### 색깔
# ![image.png](attachment:image.png)

# %%
y=[2,4,6]   

plt.plot(y, color='r') ###  색깔 color
plt.show()

# %%
y=[2,4,6]   

plt.plot(y,marker='o', markerfacecolor='m',markersize =10 ) ###  
plt.show()

# %% [markdown]
# ### 그래프 스타일 종합
# #### plot 안에 넣어야한다
# ![image.png](attachment:image.png)

# %%
### 넘파이 불러오기
import numpy as np

# %%
#연습문제
x=np.arange(7)
y=[1,4,5,8,9,5,3]

plt.plot(x,y, ls='--',color='g', marker='o')
plt.show() 
plt.plot(x,y, ls=':',color='r', marker='D', mfc='b', ms=10)
plt.show()

# %%
#연습문제2
x=np.arange(7)
y=[1,4,5,8,9,5,3]

plt.plot(x,y, ls='--',color='b', lw='5',marker='o',mfc='r',ms=15,mec='g')
plt.show()

# %%
###연습문제2 해제
x=np.arange(7)
y=[1,4,5,8,9,5,3]

plt.plot(x,y, ls='--',color='b', lw='5',marker='o',mfc='r',ms=15,mec='g',mew='5')
plt.show()

# %% [markdown]
# #### 범위 지정

# %%
x=np.arange(7)
y=[1,4,5,8,9,5,3]

plt.plot(x,y, ls='--',color='b', lw='5',marker='o',mfc='r',ms=15,mec='g',mew='5')
plt.xlim(-2,10)
plt.ylim(-5,12)
plt.show()

# %% [markdown]
# #### 틱 설정

# %%
x=np.arange(7)
y=[1,4,5,8,9,5,3]

plt.plot(x,y, ls='--',color='b', lw='5',marker='o',mfc='r',ms=15,mec='g',mew='5')
plt.xlim(-2,10)
plt.ylim(-2,10)

plt.xticks([0,3,6])
plt.yticks([0,3,6])

plt.show()

# %% [markdown]
# #### 그리드(grid)

# %%
x=np.arange(7)
y=[1,4,5,8,9,5,3]

plt.plot(x,y, ls='--',color='b', lw='5',marker='o',mfc='r',ms=15,mec='g',mew='5')
plt.xlim(-2,10)
plt.ylim(-2,10)

plt.grid()

plt.show()

# %% [markdown]
# ### 다중 플롯 그리기
# ##### 플롯 바깥에 사용하는 옵션들
# ![image.png](attachment:image.png)

# %%
x=[1,2,3,4]
y=[2,4,6,8]
z=[3,6,9,12]

plt.plot(x,label='x')
plt.plot(y,label='y')
plt.plot(z,label='z')

plt.legend() # label을 그래프에 표시해주는 함수
plt.show()

# %% [markdown]
# ### Bar chart(막대그래프)

# %%
x=[0,1,2]
y=[80,60,70]
plt.bar(x,y)
plt.show()

# %% [markdown]
# #### 연습문제
# ![image.png](attachment:image.png)

# %%
x=['a','b','c','d','e','f']
y=[80,85,70,60,50,90]
plt.bar(x,y)
plt.show()

# %% [markdown]
# #### style 적용
# + 색깔

# %%
x=['a','b','c','d','e','f']
y=[80,85,70,60,50,90]
plt.bar(x,y,color='#ffb2d9')  ### rgb코드로도 적용가능

plt.show()

# %% [markdown]
# #### 텍스트 추가

# %%
x=['a','b','c','d','e','f']
y=[80,85,70,60,50,90]
plt.bar(x,y,color='#ffb2d9') 

for i in range(6):
    plt.text(x[i],y[i],y[i],fontdict={'color':'blue',
                                     'size':14})

plt.show()

# %% [markdown]
# #### 한글 적용하기

# %%
from matplotlib import font_manager,rc

# %%
font_list=font_manager.findSystemFonts()

# %%
for i in range(len(font_list)):
    print(font_list[i],i)
# Out:
# C:\Windows\Fonts\Inkfree.ttf 0
# C:\Windows\Fonts\seguiemj.ttf 1
# C:\WINDOWS\Fonts\comicbd.ttf 2
# C:\Windows\Fonts\palabi.ttf 3
# C:\WINDOWS\Fonts\Nirmala.ttf 4
# C:\Windows\Fonts\ebrima.ttf 5
# C:\Windows\Fonts\ARIALN.TTF 6
# C:\WINDOWS\Fonts\HMKMAMI.TTF 7
# C:\WINDOWS\Fonts\palabi.ttf 8
# C:\Windows\Fonts\HMFMMUEX.TTC 9
# C:\Windows\Fonts\timesi.ttf 10
# C:\WINDOWS\Fonts\times.ttf 11
# C:\WINDOWS\Fonts\seguisbi.ttf 12
# C:\Windows\Fonts\Cookie-Regular.ttf 13
# C:\Windows\Fonts\HYHWPEQ.TTF 14
# C:\WINDOWS\Fonts\Candarab.ttf 15
# C:\Windows\Fonts\Limelight-Regular.ttf 16
# C:\Windows\Fonts\georgiab.ttf 17
# C:\WINDOWS\Fonts\H2MJSM.TTF 18
# C:\Windows\Fonts\comicz.ttf 19
# C:\WINDOWS\Fonts\Quicksand-Medium.ttf 20
# C:\Windows\Fonts\Cinzel-Black.ttf 21
# C:\Windows\Fonts\LEELAWDB.TTF 22
# C:\Windows\Fonts\msjh.ttc 23
# C:\Windows\Fonts\segoeuiz.ttf 24
# C:\WINDOWS\Fonts\gulim.ttc 25
# C:\WINDOWS\Fonts\HANBatangExtB.ttf 26
# C:\Windows\Fonts\courbd.ttf 27
# C:\Windows\Fonts\segmdl2.ttf 28
# C:\WINDOWS\Fonts\calibrii.ttf 29
# C:\Windows\Fonts\verdanai.ttf 30
# C:\Windows\Fonts\micross.ttf 31
# C:\WINDOWS\Fonts\DoppioOne-Regular.ttf 32
# C:\Windows\Fonts\HanSantteutDotum-Regular.ttf 33
# C:\WINDOWS\Fonts\mmrtextb.ttf 34
# C:\Windows\Fonts\Quicksand-Regular.ttf 35
# C:\WINDOWS\Fonts\constan.ttf 36
# C:\Windows\Fonts\MarcellusSC-Regular.ttf 37
# C:\WINDOWS\Fonts\corbelz.ttf 38
# C:\WINDOWS\Fonts\HANBatang.ttf 39
# C:\Windows\Fonts\UbuntuMono-Regular.ttf 40
# C:\WINDOWS\Fonts\verdana.ttf 41
# C:\Windows\Fonts\cour.ttf 42
# C:\Windows\Fonts\YuGothB.ttc 43
# C:\WINDOWS\Fonts\Megrim.ttf 44
# C:\Windows\Fonts\DoppioOne-Regular.ttf 45
# C:\Windows\Fonts\segoeui.ttf 46
# C:\Windows\Fonts\msjhbd.ttc 47
# C:\WINDOWS\Fonts\verdanab.ttf 48
# C:\Windows\Fonts\arialbd.ttf 49
# C:\WINDOWS\Fonts\Kalam-Bold.ttf 50
# C:\Windows\Fonts\bahnschrift.ttf 51
# C:\WINDOWS\Fonts\ANTQUABI.TTF 52
# C:\WINDOWS\Fonts\ANTQUAB.TTF 53
# C:\WINDOWS\Fonts\impact.ttf 54
# C:\WINDOWS\Fonts\LeelawUI.ttf 55
# C:\WINDOWS\Fonts\UbuntuMono-Bold.ttf 56
# C:\WINDOWS\Fonts\Limelight-Regular.ttf 57
# C:\WINDOWS\Fonts\BungeeInline-Regular.ttf 58
# C:\Windows\Fonts\comicbd.ttf 59
# C:\WINDOWS\Fonts\Kalam-Regular.ttf 60
# C:\WINDOWS\Fonts\Candaraz.ttf 61
# C:\WINDOWS\Fonts\DUBAI-MEDIUM.TTF 62
# C:\WINDOWS\Fonts\H2GSRB.TTF 63
# C:\WINDOWS\Fonts\segoeuii.ttf 64
# C:\Windows\Fonts\palab.ttf 65
# C:\WINDOWS\Fonts\DUBAI-LIGHT.TTF 66
# C:\WINDOWS\Fonts\BOOKOS.TTF 67
# C:\WINDOWS\Fonts\H2HDRM.TTF 68
# C:\WINDOWS\Fonts\msyhl.ttc 69
# C:\WINDOWS\Fonts\calibrib.ttf 70
# C:\WINDOWS\Fonts\NotoSans-Regular.ttf 71
# C:\WINDOWS\Fonts\ANTQUAI.TTF 72
# C:\WINDOWS\Fonts\LeelUIsl.ttf 73
# C:\Windows\Fonts\corbeli.ttf 74
# C:\Windows\Fonts\MontserratSubrayada-Bold.ttf 75
# C:\Windows\Fonts\calibriz.ttf 76
# C:\WINDOWS\Fonts\constani.ttf 77
# C:\WINDOWS\Fonts\MarcellusSC-Regular.ttf 78
# C:\WINDOWS\Fonts\Quicksand-Bold.ttf 79
# C:\Windows\Fonts\msjhl.ttc 80
# C:\WINDOWS\Fonts\NirmalaB.ttf 81
# C:\Windows\Fonts\NirmalaB.ttf 82
# C:\Windows\Fonts\GARAIT.TTF 83
# C:\WINDOWS\Fonts\MTCORSVA.TTF 84
# C:\Windows\Fonts\NotoSans-Italic.ttf 85
# C:\Windows\Fonts\LeelaUIb.ttf 86
# C:\Windows\Fonts\taile.ttf 87
# C:\Windows\Fonts\RussoOne-Regular.ttf 88
# C:\WINDOWS\Fonts\BOOKOSBI.TTF 89
# C:\WINDOWS\Fonts\BOOKOSI.TTF 90
# C:\WINDOWS\Fonts\malgunsl.ttf 91
# C:\Windows\Fonts\CabinSketch-Regular.ttf 92
# C:\WINDOWS\Fonts\NotoSans-Bold.ttf 93
# C:\WINDOWS\Fonts\LEELAWAD.TTF 94
# C:\WINDOWS\Fonts\Yellowtail-Regular.ttf 95
# C:\WINDOWS\Fonts\mvboli.ttf 96
# C:\WINDOWS\Fonts\BSSYM7.TTF 97
# C:\WINDOWS\Fonts\CENTURY.TTF 98
# C:\Windows\Fonts\malgunsl.ttf 99
# C:\WINDOWS\Fonts\segoeuib.ttf 100
# C:\Windows\Fonts\YuGothL.ttc 101
# C:\Windows\Fonts\H2PORM.TTF 102
# C:\WINDOWS\Fonts\calibri.ttf 103
# C:\WINDOWS\Fonts\GARA.TTF 104
# C:\WINDOWS\Fonts\corbelli.ttf 105
# C:\WINDOWS\Fonts\HANWing2.ttf 106
# C:\Windows\Fonts\consolaz.ttf 107
# C:\Windows\Fonts\cambriaz.ttf 108
# C:\WINDOWS\Fonts\NotoSans-Italic.ttf 109
# C:\Windows\Fonts\seguisym.ttf 110
# C:\WINDOWS\Fonts\Gabriola.ttf 111
# C:\Windows\Fonts\trebucit.ttf 112
# C:\WINDOWS\Fonts\H2MJRE.TTF 113
# C:\Windows\Fonts\NirmalaS.ttf 114
# C:\Windows\Fonts\trebuc.ttf 115
# C:\Windows\Fonts\Hancom Gothic Bold.ttf 116
# C:\Windows\Fonts\phagspa.ttf 117
# C:\Windows\Fonts\BungeeInline-Regular.ttf 118
# C:\Windows\Fonts\Lemon-Regular.ttf 119
# C:\WINDOWS\Fonts\ARIALNB.TTF 120
# C:\Windows\Fonts\monbaiti.ttf 121
# C:\Windows\Fonts\consolai.ttf 122
# C:\WINDOWS\Fonts\Quicksand-Light.ttf 123
# C:\Windows\Fonts\HMKMAMI.TTF 124
# C:\WINDOWS\Fonts\HYHWPEQ.TTF 125
# C:\WINDOWS\Fonts\consolaz.ttf 126
# C:\WINDOWS\Fonts\H2GTRE.TTF 127
# C:\Windows\Fonts\mvboli.ttf 128
# C:\WINDOWS\Fonts\georgia.ttf 129
# C:\WINDOWS\Fonts\Sitka.ttc 130
# C:\WINDOWS\Fonts\trebucbd.ttf 131
# C:\Windows\Fonts\H2MKPB.TTF 132
# C:\Windows\Fonts\wingding.ttf 133
# C:\Windows\Fonts\GOTHICI.TTF 134
# C:\WINDOWS\Fonts\holomdl2.ttf 135
# C:\Windows\Fonts\simsun.ttc 136
# C:\WINDOWS\Fonts\taileb.ttf 137
# C:\Windows\Fonts\Nirmala.ttf 138
# C:\WINDOWS\Fonts\consolab.ttf 139
# C:\WINDOWS\Fonts\JUMJA.TTF 140
# C:\WINDOWS\Fonts\javatext.ttf 141
# C:\WINDOWS\Fonts\trebuc.ttf 142
# C:\WINDOWS\Fonts\comicz.ttf 143
# C:\WINDOWS\Fonts\palai.ttf 144
# C:\Windows\Fonts\H2GTRM.TTF 145
# C:\WINDOWS\Fonts\ARIALNBI.TTF 146
# C:\WINDOWS\Fonts\YuGothR.ttc 147
# C:\Windows\Fonts\ariali.ttf 148
# C:\WINDOWS\Fonts\Hancom Gothic Regular.ttf 149
# C:\Windows\Fonts\verdanaz.ttf 150
# C:\WINDOWS\Fonts\HMFMPYUN.TTF 151
# C:\WINDOWS\Fonts\msjhl.ttc 152
# C:\Windows\Fonts\LeelUIsl.ttf 153
# C:\WINDOWS\Fonts\HMFMOLD.TTF 154
# C:\Windows\Fonts\Candara.ttf 155
# C:\WINDOWS\Fonts\segoeui.ttf 156
# C:\Windows\Fonts\gadugib.ttf 157
# C:\Windows\Fonts\segoeuil.ttf 158
# C:\WINDOWS\Fonts\HMKMRHD.TTF 159
# C:\Windows\Fonts\verdanab.ttf 160
# C:\Windows\Fonts\seguisbi.ttf 161
# C:\Windows\Fonts\Sitka.ttc 162
# C:\WINDOWS\Fonts\framd.ttf 163
# C:\WINDOWS\Fonts\H2MKPB.TTF 164
# C:\Windows\Fonts\GOTHIC.TTF 165
# C:\Windows\Fonts\timesbi.ttf 166
# C:\WINDOWS\Fonts\MSUIGHUR.TTF 167
# C:\WINDOWS\Fonts\corbelb.ttf 168
# C:\WINDOWS\Fonts\REFSPCL.TTF 169
# C:\Windows\Fonts\javatext.ttf 170
# C:\Windows\Fonts\taileb.ttf 171
# C:\WINDOWS\Fonts\himalaya.ttf 172
# C:\WINDOWS\Fonts\arialbd.ttf 173
# C:\WINDOWS\Fonts\PermanentMarker.ttf 174
# C:\WINDOWS\Fonts\CabinSketch-Bold.ttf 175
# C:\Windows\Fonts\Quicksand-Medium.ttf 176
# C:\WINDOWS\Fonts\corbell.ttf 177
# C:\WINDOWS\Fonts\taile.ttf 178
# C:\Windows\Fonts\Candarab.ttf 179
# C:\WINDOWS\Fonts\corbeli.ttf 180
# C:\WINDOWS\Fonts\Inkfree.ttf 181
# C:\WINDOWS\Fonts\Candarali.ttf 182
# C:\Windows\Fonts\couri.ttf 183
# C:\WINDOWS\Fonts\timesbi.ttf 184
# C:\Windows\Fonts\l_10646.ttf 185
# C:\Windows\Fonts\HMKMMAG.TTF 186
# C:\WINDOWS\Fonts\cambria.ttc 187
# C:\Windows\Fonts\constani.ttf 188
# C:\WINDOWS\Fonts\cambriai.ttf 189
# C:\Windows\Fonts\seguibli.ttf 190
# C:\Windows\Fonts\Gabriola.ttf 191
# C:\Windows\Fonts\segoepr.ttf 192
# C:\WINDOWS\Fonts\BowlbyOneSC-Regular.ttf 193
# C:\WINDOWS\Fonts\D2Coding.ttc 194
# C:\WINDOWS\Fonts\HANBatangExtBB.ttf 195
# C:\WINDOWS\Fonts\Hancom Gothic Bold.ttf 196
# C:\Windows\Fonts\cambriab.ttf 197
# C:\Windows\Fonts\seguili.ttf 198
# C:\WINDOWS\Fonts\ariali.ttf 199
# C:\WINDOWS\Fonts\ebrimabd.ttf 200
# C:\Windows\Fonts\gulim.ttc 201
# C:\WINDOWS\Fonts\palab.ttf 202
# C:\Windows\Fonts\ntailu.ttf 203
# C:\WINDOWS\Fonts\msyhbd.ttc 204
# C:\WINDOWS\Fonts\GARABD.TTF 205
# C:\WINDOWS\Fonts\MSUIGHUB.TTF 206
# C:\Windows\Fonts\REFSAN.TTF 207
# C:\Windows\Fonts\Candarai.ttf 208
# C:\WINDOWS\Fonts\Candara.ttf 209
# C:\Windows\Fonts\msgothic.ttc 210
# C:\WINDOWS\Fonts\H2GPRM.TTF 211
# C:\Windows\Fonts\calibrili.ttf 212
# C:\WINDOWS\Fonts\H2PORL.TTF 213
# C:\WINDOWS\Fonts\Kalam-Light.ttf 214
# C:\Windows\Fonts\MTEXTRA.TTF 215
# C:\WINDOWS\Fonts\comic.ttf 216
# C:\WINDOWS\Fonts\arialbi.ttf 217
# C:\WINDOWS\Fonts\HanSantteutDotumRegular.ttf 218
# C:\WINDOWS\Fonts\LEELAWDB.TTF 219
# C:\WINDOWS\Fonts\msyi.ttf 220
# C:\WINDOWS\Fonts\BKANT.TTF 221
# C:\WINDOWS\Fonts\DUBAI-BOLD.TTF 222
# C:\WINDOWS\Fonts\wingding.ttf 223
# C:\Windows\Fonts\calibrii.ttf 224
# C:\Windows\Fonts\msyhl.ttc 225
# C:\WINDOWS\Fonts\arial.ttf 226
# C:\Windows\Fonts\Candaraz.ttf 227
# C:\WINDOWS\Fonts\ARIALNI.TTF 228
# C:\WINDOWS\Fonts\corbel.ttf 229
# C:\Windows\Fonts\palai.ttf 230
# C:\Windows\Fonts\himalaya.ttf 231
# C:\WINDOWS\Fonts\gadugib.ttf 232
# C:\Windows\Fonts\HancomEQN.ttf 233
# C:\Windows\Fonts\Inter-Regular-slnt=0.ttf 234
# C:\WINDOWS\Fonts\HMFMMUEX.TTC 235
# C:\WINDOWS\Fonts\Cookie-Regular.ttf 236
# C:\WINDOWS\Fonts\calibriz.ttf 237
# C:\Windows\Fonts\mmrtext.ttf 238
# C:\WINDOWS\Fonts\SigmarOne-Regular.ttf 239
# C:\Windows\Fonts\MSUIGHUB.TTF 240
# C:\Windows\Fonts\consolab.ttf 241
# C:\WINDOWS\Fonts\tahoma.ttf 242
# C:\Windows\Fonts\teamviewer15.otf 243
# C:\WINDOWS\Fonts\mmrtext.ttf 244
# C:\Windows\Fonts\DUBAI-BOLD.TTF 245
# C:\WINDOWS\Fonts\YuGothM.ttc 246
# C:\WINDOWS\Fonts\MTEXTRA.TTF 247
# C:\Windows\Fonts\H2GSRB.TTF 248
# C:\Windows\Fonts\Hancom Gothic Regular.ttf 249
# C:\Windows\Fonts\ANTQUABI.TTF 250
# C:\Windows\Fonts\HANBatangExtB.ttf 251
# C:\Windows\Fonts\constanz.ttf 252
# C:\WINDOWS\Fonts\WINGDNG3.TTF 253
# C:\Windows\Fonts\Orbitron-Bold.ttf 254
# C:\WINDOWS\Fonts\GARAIT.TTF 255
# C:\Windows\Fonts\georgiai.ttf 256
# C:\WINDOWS\Fonts\segoeprb.ttf 257
# C:\Windows\Fonts\corbel.ttf 258
# C:\WINDOWS\Fonts\segoesc.ttf 259
# C:\WINDOWS\Fonts\l_10646.ttf 260
# C:\Windows\Fonts\SigmarOne-Regular.ttf 261
# C:\WINDOWS\Fonts\cambriaz.ttf 262
# C:\WINDOWS\Fonts\HANDotum.ttf 263
# C:\Windows\Fonts\georgia.ttf 264
# C:\WINDOWS\Fonts\courbi.ttf 265
# C:\WINDOWS\Fonts\seguibl.ttf 266
# C:\Windows\Fonts\HANDotum.ttf 267
# C:\Windows\Fonts\holomdl2.ttf 268
# C:\Windows\Fonts\ARIALNBI.TTF 269
# C:\WINDOWS\Fonts\constanz.ttf 270
# C:\WINDOWS\Fonts\timesbd.ttf 271
# C:\WINDOWS\Fonts\segoeuiz.ttf 272
# C:\WINDOWS\Fonts\georgiai.ttf 273
# C:\WINDOWS\Fonts\GOTHICB.TTF 274
# C:\WINDOWS\Fonts\NotoSans-BoldItalic.ttf 275
# C:\Windows\Fonts\H2PORL.TTF 276
# C:\Windows\Fonts\HMFMOLD.TTF 277
# C:\Windows\Fonts\GreatVibes-Regular.ttf 278
# C:\WINDOWS\Fonts\SitkaZ.ttc 279
# C:\Windows\Fonts\BKANT.TTF 280
# C:\WINDOWS\Fonts\calibrili.ttf 281
# C:\Windows\Fonts\msyi.ttf 282
# C:\WINDOWS\Fonts\batang.ttc 283
# C:\Windows\Fonts\H2SA1M.TTF 284
# C:\Windows\Fonts\constanb.ttf 285
# C:\Windows\Fonts\segoeuib.ttf 286
# C:\Windows\Fonts\BOOKOSI.TTF 287
# C:\WINDOWS\Fonts\seguisli.ttf 288
# C:\WINDOWS\Fonts\seguisym.ttf 289
# C:\Windows\Fonts\PermanentMarker.ttf 290
# C:\Windows\Fonts\WINGDNG2.TTF 291
# C:\Windows\Fonts\HANWing2.ttf 292
# C:\WINDOWS\Fonts\marlett.ttf 293
# C:\WINDOWS\Fonts\verdanaz.ttf 294
# C:\WINDOWS\Fonts\cour.ttf 295
# C:\WINDOWS\Fonts\msjhbd.ttc 296
# C:\WINDOWS\Fonts\GreatVibes-Regular.ttf 297
# C:\Windows\Fonts\calibri.ttf 298
# C:\WINDOWS\Fonts\bahnschrift.ttf 299
# C:\WINDOWS\Fonts\HANBatangB.ttf 300
# C:\Windows\Fonts\H2MJRE.TTF 301
# C:\Windows\Fonts\courbi.ttf 302
# C:\WINDOWS\Fonts\georgiaz.ttf 303
# C:\WINDOWS\Fonts\consola.ttf 304
# C:\Windows\Fonts\HANDotumExt.ttf 305
# C:\WINDOWS\Fonts\Inter-Bold-slnt=0.ttf 306
# C:\WINDOWS\Fonts\seguihis.ttf 307
# C:\WINDOWS\Fonts\sylfaen.ttf 308
# C:\Windows\Fonts\msyhbd.ttc 309
# C:\WINDOWS\Fonts\Playball-Regular.ttf 310
# C:\Windows\Fonts\LeelawUI.ttf 311
# C:\Windows\Fonts\framd.ttf 312
# C:\Windows\Fonts\segoeuisl.ttf 313
# C:\Windows\Fonts\msyh.ttc 314
# C:\Windows\Fonts\simsunb.ttf 315
# C:\Windows\Fonts\NGULIM.TTF 316
# C:\Windows\Fonts\HANBatang.ttf 317
# C:\Windows\Fonts\mingliub.ttc 318
# C:\Windows\Fonts\BOOKOSB.TTF 319
# C:\WINDOWS\Fonts\Candarai.ttf 320
# C:\Windows\Fonts\ariblk.ttf 321
# C:\WINDOWS\Fonts\HANDotumExt.ttf 322
# C:\Windows\Fonts\HanSantteutDotum-Bold.ttf 323
# C:\Windows\Fonts\seguisli.ttf 324
# C:\Windows\Fonts\cambria.ttc 325
# C:\Windows\Fonts\GARABD.TTF 326
# C:\Windows\Fonts\pala.ttf 327
# C:\WINDOWS\Fonts\segmdl2.ttf 328
# C:\WINDOWS\Fonts\timesi.ttf 329
# C:\Windows\Fonts\LEELAWAD.TTF 330
# C:\Windows\Fonts\HANBatangB.ttf 331
# C:\Windows\Fonts\Teko-SemiBold.ttf 332
# C:\WINDOWS\Fonts\Cinzel-Black.ttf 333
# C:\Windows\Fonts\HMFMPYUN.TTF 334
# C:\Windows\Fonts\DUBAI-REGULAR.TTF 335
# C:\WINDOWS\Fonts\ariblk.ttf 336
# C:\WINDOWS\Fonts\trebucbi.ttf 337
# C:\WINDOWS\Fonts\seguili.ttf 338
# C:\WINDOWS\Fonts\georgiab.ttf 339
# C:\WINDOWS\Fonts\comici.ttf 340
# C:\WINDOWS\Fonts\CabinSketch-Regular.ttf 341
# C:\Windows\Fonts\HanSantteutDotumBold.ttf 342
# C:\Windows\Fonts\Shrikhand-Regular.ttf 343
# C:\Windows\Fonts\mmrtextb.ttf 344
# C:\Windows\Fonts\gadugi.ttf 345
# C:\Windows\Fonts\webdings.ttf 346
# C:\WINDOWS\Fonts\monbaiti.ttf 347
# C:\Windows\Fonts\consola.ttf 348
# C:\WINDOWS\Fonts\REFSAN.TTF 349
# C:\Windows\Fonts\H2GTRE.TTF 350
# C:\Windows\Fonts\DUBAI-MEDIUM.TTF 351
# C:\Windows\Fonts\ebrimabd.ttf 352
# C:\Windows\Fonts\ARIALNI.TTF 353
# C:\Windows\Fonts\seguibl.ttf 354
# C:\Windows\Fonts\SitkaI.ttc 355
# C:\Windows\Fonts\calibril.ttf 356
# C:\WINDOWS\Fonts\msyh.ttc 357
# C:\WINDOWS\Fonts\framdit.ttf 358
# C:\WINDOWS\Fonts\Orbitron-Bold.ttf 359
# C:\Windows\Fonts\HANDotumB.ttf 360
# C:\WINDOWS\Fonts\malgun.ttf 361
# C:\WINDOWS\Fonts\symbol.ttf 362
# C:\Windows\Fonts\REFSPCL.TTF 363
# C:\Windows\Fonts\comic.ttf 364
# C:\WINDOWS\Fonts\simsunb.ttf 365
# C:\Windows\Fonts\JUMJA.TTF 366
# C:\WINDOWS\Fonts\BOOKOSB.TTF 367
# C:\WINDOWS\Fonts\gadugi.ttf 368
# C:\WINDOWS\Fonts\micross.ttf 369
# C:\Windows\Fonts\segoescb.ttf 370
# C:\WINDOWS\Fonts\ntailub.ttf 371
# C:\WINDOWS\Fonts\phagspab.ttf 372
# C:\WINDOWS\Fonts\DUBAI-REGULAR.TTF 373
# C:\Windows\Fonts\lucon.ttf 374
# C:\WINDOWS\Fonts\seguiemj.ttf 375
# C:\Windows\Fonts\H2GPRM.TTF 376
# C:\Windows\Fonts\cambriai.ttf 377
# C:\Windows\Fonts\Candaral.ttf 378
# C:\WINDOWS\Fonts\MontserratSubrayada-Bold.ttf 379
# C:\Windows\Fonts\BOOKOSBI.TTF 380
# C:\WINDOWS\Fonts\segoepr.ttf 381
# C:\WINDOWS\Fonts\FugazOne-Regular.ttf 382
# C:\Windows\Fonts\ANTQUAI.TTF 383
# C:\WINDOWS\Fonts\segoeuil.ttf 384
# C:\WINDOWS\Fonts\teamviewer15.otf 385
# C:\WINDOWS\Fonts\ntailu.ttf 386
# C:\WINDOWS\Fonts\malgunbd.ttf 387
# C:\Windows\Fonts\BowlbyOneSC-Regular.ttf 388
# C:\WINDOWS\Fonts\couri.ttf 389
# C:\Windows\Fonts\Kalam-Regular.ttf 390
# C:\Windows\Fonts\segoeprb.ttf 391
# C:\WINDOWS\Fonts\NGULIM.TTF 392
# C:\Windows\Fonts\Courgette-Regular.ttf 393
# C:\WINDOWS\Fonts\courbd.ttf 394
# C:\Windows\Fonts\tahoma.ttf 395
# C:\Windows\Fonts\YuGothR.ttc 396
# C:\WINDOWS\Fonts\HanSantteutDotumBold.ttf 397
# C:\WINDOWS\Fonts\HanSantteutDotum-Regular.ttf 398
# C:\Windows\Fonts\phagspab.ttf 399
# C:\WINDOWS\Fonts\msjh.ttc 400
# C:\WINDOWS\Fonts\UbuntuMono-Regular.ttf 401
# C:\Windows\Fonts\arialbi.ttf 402
# C:\Windows\Fonts\tahomabd.ttf 403
# C:\WINDOWS\Fonts\segoeuisl.ttf 404
# C:\WINDOWS\Fonts\trebucit.ttf 405
# C:\Windows\Fonts\verdana.ttf 406
# C:\Windows\Fonts\H2MJSM.TTF 407
# C:\Windows\Fonts\BOOKOS.TTF 408
# C:\Windows\Fonts\timesbd.ttf 409
# C:\Windows\Fonts\SitkaZ.ttc 410
# C:\Windows\Fonts\Playball-Regular.ttf 411
# C:\Windows\Fonts\MTCORSVA.TTF 412
# C:\Windows\Fonts\arial.ttf 413
# C:\Windows\Fonts\MSUIGHUR.TTF 414
# C:\Windows\Fonts\seguihis.ttf 415
# C:\WINDOWS\Fonts\ebrima.ttf 416
# C:\Windows\Fonts\D2Coding.ttc 417
# C:\WINDOWS\Fonts\RussoOne-Regular.ttf 418
# C:\WINDOWS\Fonts\verdanai.ttf 419
# C:\Windows\Fonts\GOTHICB.TTF 420
# C:\WINDOWS\Fonts\HancomEQN.ttf 421
# C:\Windows\Fonts\Megrim.ttf 422
# C:\Windows\Fonts\malgunbd.ttf 423
# C:\Windows\Fonts\Candarali.ttf 424
# C:\WINDOWS\Fonts\Courgette-Regular.ttf 425
# C:\WINDOWS\Fonts\tahomabd.ttf 426
# C:\WINDOWS\Fonts\pala.ttf 427
# C:\WINDOWS\Fonts\segoescb.ttf 428
# C:\WINDOWS\Fonts\euphorig.ttf 429
# C:\WINDOWS\Fonts\seguisb.ttf 430
# C:\Windows\Fonts\HMKMRHD.TTF 431
# C:\Windows\Fonts\GARA.TTF 432
# C:\Windows\Fonts\Inter-Bold-slnt=0.ttf 433
# C:\WINDOWS\Fonts\mingliub.ttc 434
# C:\Windows\Fonts\CENTURY.TTF 435
# C:\Windows\Fonts\times.ttf 436
# C:\Windows\Fonts\segoeuii.ttf 437
# C:\WINDOWS\Fonts\H2PORM.TTF 438
# C:\WINDOWS\Fonts\Lemon-Regular.ttf 439
# C:\Windows\Fonts\HANBatangExtBB.ttf 440
# C:\Windows\Fonts\Kalam-Light.ttf 441
# C:\WINDOWS\Fonts\H2GTRM.TTF 442
# C:\Windows\Fonts\symbol.ttf 443
# C:\WINDOWS\Fonts\cambriab.ttf 444
# C:\WINDOWS\Fonts\Inter-Regular-slnt=0.ttf 445
# C:\WINDOWS\Fonts\H2SA1M.TTF 446
# C:\WINDOWS\Fonts\SitkaB.ttc 447
# C:\Windows\Fonts\Quicksand-Light.ttf 448
# C:\WINDOWS\Fonts\NirmalaS.ttf 449
# C:\Windows\Fonts\ARIALNB.TTF 450
# C:\WINDOWS\Fonts\Quicksand-Regular.ttf 451
# C:\WINDOWS\Fonts\GOTHICI.TTF 452
# C:\WINDOWS\Fonts\seguibli.ttf 453
# C:\Windows\Fonts\HanSantteutDotumRegular.ttf 454
# C:\Windows\Fonts\batang.ttc 455
# C:\WINDOWS\Fonts\YuGothB.ttc 456
# C:\Windows\Fonts\malgun.ttf 457
# C:\WINDOWS\Fonts\consolai.ttf 458
# C:\WINDOWS\Fonts\HMKMMAG.TTF 459
# C:\WINDOWS\Fonts\msgothic.ttc 460
# C:\WINDOWS\Fonts\webdings.ttf 461
# C:\WINDOWS\Fonts\Teko-SemiBold.ttf 462
# C:\Windows\Fonts\corbell.ttf 463
# C:\WINDOWS\Fonts\Shrikhand-Regular.ttf 464
# C:\Windows\Fonts\trebucbd.ttf 465
# C:\WINDOWS\Fonts\WINGDNG2.TTF 466
# C:\WINDOWS\Fonts\HanSantteutDotum-Bold.ttf 467
# C:\Windows\Fonts\HANBatangExt.ttf 468
# C:\WINDOWS\Fonts\HANBatangExt.ttf 469
# C:\WINDOWS\Fonts\YuGothL.ttc 470
# C:\Windows\Fonts\WINGDNG3.TTF 471
# C:\Windows\Fonts\BSSYM7.TTF 472
# C:\Windows\Fonts\YuGothM.ttc 473
# C:\Windows\Fonts\calibrib.ttf 474
# C:\Windows\Fonts\FugazOne-Regular.ttf 475
# C:\WINDOWS\Fonts\LeelaUIb.ttf 476
# C:\Windows\Fonts\H2HDRM.TTF 477
# C:\Windows\Fonts\constan.ttf 478
# C:\Windows\Fonts\comici.ttf 479
# C:\WINDOWS\Fonts\constanb.ttf 480
# C:\Windows\Fonts\DUBAI-LIGHT.TTF 481
# C:\Windows\Fonts\ntailub.ttf 482
# C:\Windows\Fonts\georgiaz.ttf 483
# C:\Windows\Fonts\seguisb.ttf 484
# C:\Windows\Fonts\trebucbi.ttf 485
# C:\Windows\Fonts\sylfaen.ttf 486
# C:\Windows\Fonts\impact.ttf 487
# C:\WINDOWS\Fonts\lucon.ttf 488
# C:\WINDOWS\Fonts\SitkaI.ttc 489
# C:\Windows\Fonts\euphorig.ttf 490
# C:\WINDOWS\Fonts\phagspa.ttf 491
# C:\WINDOWS\Fonts\ARIALN.TTF 492
# C:\Windows\Fonts\framdit.ttf 493
# C:\Windows\Fonts\corbelb.ttf 494
# C:\Windows\Fonts\Yellowtail-Regular.ttf 495
# C:\WINDOWS\Fonts\GOTHICBI.TTF 496
# C:\WINDOWS\Fonts\HANDotumB.ttf 497
# C:\WINDOWS\Fonts\simsun.ttc 498
# C:\WINDOWS\Fonts\calibril.ttf 499
# C:\Windows\Fonts\ANTQUAB.TTF 500
# C:\Windows\Fonts\segoesc.ttf 501
# C:\Windows\Fonts\GOTHICBI.TTF 502
# C:\Windows\Fonts\corbelz.ttf 503
# C:\Windows\Fonts\corbelli.ttf 504
# C:\WINDOWS\Fonts\GOTHIC.TTF 505
# C:\Windows\Fonts\SitkaB.ttc 506
# C:\WINDOWS\Fonts\Candaral.ttf 507

# %%
### 굴림체가 246번 인 상태 d2코딩 181번
a=font_manager.FontProperties(fname=font_list[181])

# %%
a.get_name()
# Out:
# 'Ink Free'

# %%
rc('font',family='D2Coding')

# %%
x=['a','b','c','d','e','f']
y=[80,85,70,60,50,90]
plt.bar(x,y,color='#ffb2d9') 

for i in range(6):
    plt.text(x[i],y[i],'하이',fontdict={'color':'blue',
                                     'size':14})

plt.show()

# %% [markdown]
# ### 전국교통사고 2017 데이터 시각화

# %%
###pandas 불러오기
import pandas as pd

# %%
data=pd.read_csv('./data/Traffic_Accident_2017.csv', encoding='euc-kr')

# %%
data.head()
# Out:
#     발생년      발생년월일시  발생분  주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수  ... 도로형태_대분류  \
# 0  2017  2017010101   15  야간  일     1     2     1     0       0  ...      단일로
# 1  2017  2017010102   28  야간  일     1     1     0     0       0  ...      교차로
# 2  2017  2017010102   43  야간  일     1     2     0     1       0  ...      단일로
# 3  2017  2017010102   22  야간  일     1     1     0     0       0  ...      단일로
# 4  2017  2017010104   37  야간  일     1     1     0     0       0  ...      단일로
#
#     도로형태 당사자종별_1당_대분류 당사자종별_1당 당사자종별_2당_대분류 당사자종별_2당 발생위치X_UTMK 발생위치Y_UTMK  \
# 0  기타단일로          승용차      승용차          승용차      승용차     933501    1700129
# 1  교차로부근          승용차      승용차          보행자      보행자     967570    1944453
# 2  기타단일로          승용차      승용차          승용차      승용차     916497    1842880
# 3  기타단일로          승용차      승용차           없음       없음     961608    1864573
# 4  기타단일로          승용차      승용차          보행자      보행자     946778    1941695
#
#            경도         위도
# 0  126.768634  35.294464
# 1  127.133107  37.498741
# 2  126.566631  36.580069
# 3  127.069759  36.778505
# 4  126.898094  37.472946
#
# [5 rows x 27 columns]

# %% [markdown]
#  요일별 교통사고 시각화
#  ![image.png](attachment:image.png)

# %%
temp=data['요일'].value_counts()
temp
# Out:
# 화    608
# 월    603
# 금    603
# 토    596
# 목    586
# 수    565
# 일    504
# Name: 요일, dtype: int64

# %%
y=temp[['월','화','수','목','금','토','일']]

# %%
x=['월','화','수','목','금','토','일']
plt.bar(x,y)
plt.ylim(500,620)
plt.xlabel('요일')
plt.ylabel('사고 건수')
plt.title('요일별 교통사고 건수')

plt.show()

# %% [markdown]
# ### 차대차 사건 중 죽거나 다친 사람이 많은 발생지시도 시각화
# ![image.png](attachment:image.png)

# %%
#data.info()
#data['사상자수']
#data.columns
#data['사고유형_대분류'].value_counts()
#data['발생지시도'].value_counts()
# Out:
# 차대차      1642
# 차대사람     1601
# 차량단독      821
# 철길건널목       1
# Name: 사고유형_대분류, dtype: int64

# %%
x1=data['발생지시도'][data['사고유형_대분류']=='차대차'].value_counts()

x1_1=[['강원','경기','경남','경북','광주','대구','대전','부산','서울 지역','세종','울산','인천','전남','전북','제주','충남',
      '충북']]
y1=data[['사상자수']].value_counts()

plt.bar(x1_1,y1)
#plt.ylim(500,620)
#plt.xlabel('요일')
#plt.ylabel('사고 건수')
#plt.title('요일별 교통사고 건수')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6608/2921813343.py in <module>
#       5 y1=data[['사상자수']].value_counts()
#       6
# ----> 7 plt.bar(x1_1,y1)
#       8 #plt.ylim(500,620)
#       9 #plt.xlabel('요일')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2649         x, height, width=0.8, bottom=None, *, align='center',
#    2650         data=None, **kwargs):
# -> 2651     return gca().bar(
#    2652         x, height, width=width, bottom=bottom, align=align,
#    2653         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2302                 yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
#    2303
# -> 2304         x, height, width, y, linewidth, hatch = np.broadcast_arrays(
#    2305             # Make args iterable too.
#    2306             np.atleast_1d(x), height, width, y, linewidth, hatch)
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py in broadcast_arrays(subok, *args)
#     536     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     537
# --> 538     shape = _broadcast_shape(*args)
#     539
#     540     if all(array.shape == shape for array in args):
#
# ~\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py in _broadcast_shape(*args)
#     418     # use the old-iterator because np.nditer does not handle size 0 arrays
#     419     # consistently
# --> 420     b = np.broadcast(*args[:32])
#     421     # unfortunately, it cannot handle 32 or more arguments directly
#     422     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %%
# data['발생지시도'][data['사고유형_대분류']=='차대차'].value_counts()
#data[['사상자수']].value_counts()
data.loc[:,'발생지시도']
# Out:
# 0       전남
# 1       서울
# 2       충남
# 3       충남
# 4       서울
#         ..
# 4060    경남
# 4061    부산
# 4062    강원
# 4063    경기
# 4064    대전
# Name: 발생지시도, Length: 4065, dtype: object

# %%
data.loc[:,'사상자수']
# Out:
# 0        2
# 1        1
# 2        2
# 3        1
# 4        1
#         ..
# 4060     4
# 4061     1
# 4062     1
# 4063    11
# 4064     1
# Name: 사상자수, Length: 4065, dtype: int64

# %%
### 풀이
a=data[data['사고유형_대분류']=='차대차' ]

# %%
final=a[['사상자수','발생지시도']].groupby('발생지시도').sum()

# %%
final.index
# Out:
# Index(['강원', '경기', '경남', '경북', '광주', '대구', '대전', '부산', '서울', '세종', '울산', '인천',
#        '전남', '전북', '제주', '충남', '충북'],
#       dtype='object', name='발생지시도')

# %%
plt.figure(figsize=(10,5))

plt.bar(final.index,final['사상자수'])

plt.ylabel('사상자수')
plt.xlabel('지역')
plt.title('차대차 교통사고의 사상자 수')
plt.show()

# %% [markdown]
# ### 교통사고가 가장 많이 발생하는 시간대를 알아보고 시각화 해보자.

# %%
# '0~2','3~5','6~8','9~10','11~13', .. '21~23'

# %%
rng=data['발생년월일시']
bins=[-1,3,6,9,12,15,18,21,24]
labels=['0-2','3-5','6-8','9-11','12-14','15-17','18-20','21-23']

# %%
#data.info()
data['발생년월일시']%100    ### 십의 자리까지 구하기 위해서 100으로 나눈 나머지를 구한다
# Out:
# 0        1
# 1        2
# 2        2
# 3        2
# 4        4
#         ..
# 4060    18
# 4061    18
# 4062    19
# 4063    20
# 4064    23
# Name: 발생년월일시, Length: 4065, dtype: int64

# %%
bins=[-1,2,5,8,11,14,17,20,23]  ### 실질적으로 데이터를 가르는 구간
labels=['0-2','3-5','6-8','9-11','12-14','15-17','18-20','21-23']### 라벨은 그냥 우리가 지정해주는 구간
result=pd.cut(data['발생년월일시']%100,bins=bins,labels=labels)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6608/4153713870.py in <module>
#       1 bins=[-1,2,5,8,11,14,17,20,23]  ### 실질적으로 데이터를 가르는 구간
#       2 labels=['0-2','3-5','6-8','9-11','12-14','15-17','18-20','21-23']### 라벨은 그냥 우리가 지정해주는 구간
# ----> 3 result=pd.cut(data[['발생년월일시']]%100,bins=bins,labels=labels)
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     234
#     235     original = x
# --> 236     x = _preprocess_for_cut(x)
#     237     x, dtype = _coerce_to_type(x)
#     238
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\tile.py in _preprocess_for_cut(x)
#     592         x = np.asarray(x)
#     593     if x.ndim != 1:
# --> 594         raise ValueError("Input array must be 1 dimensional")
#     595
#     596     return x
#
# ValueError: Input array must be 1 dimensional
